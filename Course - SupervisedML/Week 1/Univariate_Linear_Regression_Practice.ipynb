# %% [markdown]
# Practicing the example of predicting house prices based on a single variable (the size of the house) when fed a dataset.

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
#x_train is the input variable (size in 1000 square feet)
x_train = np.array([1.5, 1.2])
#y_train is the target (price in 1000s of dollars)
y_train = np.array([100.0, 70.0])
print("x_train =", x_train)
print(f"y_train = {y_train}")
# Out:
# x_train = [1.5 1.2]
# y_train = [100.  70.]

# %%
shape_x = x_train.shape
print(shape_x)
m = shape_x[0]
print("size of training set is", m)
# Out:
# (2,)
# size of training set is 2

# %%
plt.scatter(x_train, y_train, marker= "x", c= 'g')
plt.xlabel("Size of House in 1000 Sq. feet")
plt.ylabel("Price of House in 1000s of Dollars")
plt.title("Housing Prices")
plt.show()

# %%
def compute_model_output(x, w, b):
    """
    Computes the prediction of a linear model
    Args:
      x (ndarray (m,)): Data, m examples 
      w,b (scalar)    : model parameters  
    Returns
      y (ndarray (m,)): target values
    """
    m = x.shape[0]
    f_wb = np.zeros(m)
    for i in range(m):
        f_wb[i] = w * x[i] + b
        
    return f_wb

# %%
w = 100
b = 100

tmp_f_wb = compute_model_output(x_train, w, b,)

# Plot our model prediction
plt.plot(x_train, tmp_f_wb, c='b',label='Our Prediction')

# Plot the data points
plt.scatter(x_train, y_train, marker='x', c='r',label='Actual Values')

# Set the title
plt.title("Housing Prices")
# Set the y-axis label
plt.ylabel('Price (in 1000s of dollars)')
# Set the x-axis label
plt.xlabel('Size (1000 sqft)')
plt.legend()
plt.show()
